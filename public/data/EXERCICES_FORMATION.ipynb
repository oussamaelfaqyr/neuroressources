# %% [markdown]
# # EXERCICES SUR NUMPY

# %% [markdown]
# ![lg-6623b76c4f257-NumPys.png](attachment:05fd9567-49f8-49e1-970b-740d5e5485e1.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


print("\n" + "="*70)
print("PARTIE 1 : NUMPY - Manipulation avancée de tableaux")
print("="*70)

# =============================================================================
# Exercice 1.1 : Création et analyse de tableaux
# =============================================================================
print("\n--- Exercice 1.1 : Création et analyse ---")
# Données : âges de passagers du Titanic
ages_passagers = [22, 38, 26, 35, 35, 54, 2, 27, 14, 4]

# TODO : Convertir en tableau NumPy avec np.array()
ages = ...
# TODO : Afficher le nombre de dimensions (ndim), la forme (shape), et le type (dtype)
print(f"Nombre de dimensions : {...}")
print(f"Forme : {...}")
print(f"Type des éléments : {...}")
# TODO : Calculer l'âge moyen, minimum et maximum
age_moyen = ...
age_min = ...
age_max = ...
print(f"Âge moyen : {age_moyen:.1f} ans, Min : {age_min} ans, Max : {age_max} ans")


# =============================================================================
# Exercice 1.2 : Tableaux spéciaux
# =============================================================================
print("\n--- Exercice 1.2 : Tableaux spéciaux ---")

# TODO : Créer un tableau de 5 zéros avec np.zeros()
zeros = ...

# TODO : Créer un tableau 3x3 de uns avec np.ones()
uns = ...
# TODO : Créer un tableau de 5 nombres aléatoires entre 0 et 100 avec np.random.randint()
aleatoires = ...

# TODO : Créer un tableau de 3 nombres aléatoires (distribution normale) avec np.random.randn()
normaux = ...

# =============================================================================
# Exercice 1.3 : Séquences et redimensionnement
# =============================================================================
print("\n--- Exercice 1.3 : Séquences et redimensionnement ---")

# TODO : Créer un tableau de 10 valeurs équidistantes entre 0 et 1 avec np.linspace()
equidistant = ...

# TODO : Créer un tableau de valeurs de 5 à 15 (exclu) avec np.arange()
arange_seq = ...

# TODO : Redimensionner le tableau [1, 2, 3, 4, 5, 6] en une matrice 2x3 avec np.reshape()
tableau_1d = np.array([1, 2, 3, 4, 5, 6])
tableau_2d = ...


# =============================================================================
# Exercice 1.4 : Concatenation
# =============================================================================
print("\n--- Exercice 1.4 : Concatenation ---")

# TODO : Créer deux tableaux 1D et les concaténer horizontalement avec np.hstack()
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
hstack_result = ...

# TODO : Créer deux tableaux 1D et les concaténer verticalement avec np.vstack()
c = np.array([7, 8, 9])
vstack_result = ...

# TODO : Concaténer deux tableaux 2D avec np.concatenate() (axis=0)
d = np.array([[1, 2], [3, 4]])
e = np.array([[5, 6], [7, 8]])
concat_result = ...

# =============================================================================
# Exercice 1.5 : Filtrer avec un masque
# =============================================================================
print("\n--- Exercice 1.5 : Filtrer avec un masque ---")

# TODO : Créer un masque pour les enfants de moins de 18 ans
masque_enfants = ...

# TODO : Compter le nombre d'enfants
nb_enfants = ...

# TODO : Extraire les âges des enfants
ages_enfants = ...



# =============================================================================
# Exercice 1.6 : Extraction de colonnes
# =============================================================================
print("\n--- Exercice 1.6 : Extraction de colonnes ---")

# Données : passagers -> [âge, classe, prix]
donnees = np.array([
    [22, 3, 7.25],
    [38, 1, 71.28],
    [26, 3, 7.92],
    [35, 1, 53.10],
    [35, 3, 8.05]
])

# TODO : Extraire tous les prix 
prix = ...

# TODO : Calculer le prix moyen
prix_moyen = ...

# TODO : Extraire les âges et les classes
ages = ...
classes = ...

# %% [markdown]
# # EXERCICES SUR PANDAS

# %% [markdown]
# ![pandass1.png](attachment:bc7a8de2-14fd-4bc3-86d0-e054044ed9fc.png)

# %%
# =============================================================================
# PARTIE 2 : PANDAS 
# =============================================================================
print("\n" + "="*70)
print("PARTIE 2 : PANDAS - DataFrames et filtres")
print("="*70)

print("\n--- Exercice 2.1 : Créer un DataFrame ---")
# Données de quelques passagers
data = {
    'Name': ['Braund, Mr. Owen', 'Cumings, Mrs. John', 'Heikkinen, Miss. Laina',
             'Futrelle, Mrs. Jacques', 'Allen, Mr. William'],
    'Age': [22, 38, 26, 35, 35],
    'Sex': ['male', 'female', 'female', 'female', 'male'],
    'Survived': [0, 1, 1, 1, 0],  # 0=décédé, 1=survécu
    'Pclass': [3, 1, 3, 1, 3],
    'Fare': [7.25, 71.28, 7.92, 53.10, 8.05]
}
# TODO : Créez le DataFrame
df = None  # pd.DataFrame(data)
print("DataFrame Titanic :")
print(df)

print("\n--- Exercice 2.2 : Filtrer les survivants ---")
# TODO : Filtrez les survivants (Survived == 1)
survivants = None  
# TODO : Calculez le taux de survie en %
taux_survie = None   
print(f"Taux de survie : {taux_survie:.1f}%")

print("\n--- Exercice 2.3 : Groupby par classe ---")
# TODO : Calculez le taux de survie par classe (en %)
survie_par_classe = None  
print("Taux de survie par classe (%) :")
print(survie_par_classe)

# %% [markdown]
# # EXERCICES SUR MATPLOTLIB

# %% [markdown]
# ![matplotlib-logo-png_seeklogo-428048s1.png](attachment:8ad8ae3e-c751-4c55-ae22-8fc6c732e1e6.png)

# %%
# =============================================================================
# PARTIE 3 : MATPLOTLIB 
# =============================================================================
print("\n" + "="*70)
print("PARTIE 3 : MATPLOTLIB - Visualisation")
print("="*70)

print("\n--- Exercice 3.1 : Graphique en barres ---")
# Données : taux de survie par classe (de l'exercice précédent)
classes = [1, 2, 3]
# TODO : Récupérez les taux de survie
# taux = ...

# TODO : Créez un graphique en barres
plt.figure(figsize=(8, 5))
# plt.bar(,,)

# TODO : Ajoutez titre et labels
# plt.title(...)
# plt.xlabel(...)
# plt.ylabel(...)

plt.ylim(0, 100)
plt.show()


print("\n--- Exercice 3.2 : Scatter plot ---")
# TODO : Créez un scatter plot (âge vs prix)
plt.figure(figsize=(8, 5))
# plt.scatter(...)

# TODO : Ajoutez titre et labels
# plt.title(...)
# plt.xlabel(...)
# plt.ylabel(...)

plt.grid(True, alpha=0.3)
plt.show()
